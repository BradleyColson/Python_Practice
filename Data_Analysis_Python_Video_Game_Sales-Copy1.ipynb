# %%
#Call pandas a python data analysis library
import pandas as pd

# %%
#Read in file to analyse
df = pd.read_csv(r"C:\Users\Bradl\downloads\vgsales.csv")

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
#Get the basic headers on the file
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
#Understand the size of the file and object types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
#See basic stats on the data
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
#Which video game had the highest sales in 2010?
#Calling the year and specifically year 2010

df[df["Year"] == 2010]
# Out:
#         Rank                                               Name Platform  \
# 15        16                                 Kinect Adventures!     X360
# 26        27                        Pokemon Black/Pokemon White       DS
# 31        32                            Call of Duty: Black Ops     X360
# 40        41                            Call of Duty: Black Ops      PS3
# 54        55                                     Gran Turismo 5      PS3
# ...      ...                                                ...      ...
# 16437  16440              The Cages: Pro Style Batting Practice      Wii
# 16478  16481                 Ishin no Arashi: Shippuu Ryuumeden       DS
# 16487  16490          Slotter Mania P: Tetsuya Shinjuku vs Ueno      PSP
# 16501  16504  Transformers: War for Cybertron (XBox 360, PS3...       PC
# 16596  16599                                         Know How 2       DS
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 15     2010.0          Misc        Microsoft Game Studios     14.97      4.94
# 26     2010.0  Role-Playing                      Nintendo      5.57      3.28
# 31     2010.0       Shooter                    Activision      9.67      3.73
# 40     2010.0       Shooter                    Activision      5.98      4.44
# 54     2010.0        Racing   Sony Computer Entertainment      2.96      4.88
# ...       ...           ...                           ...       ...       ...
# 16437  2010.0        Sports  Konami Digital Entertainment      0.01      0.00
# 16478  2010.0      Strategy                    Tecmo Koei      0.00      0.00
# 16487  2010.0          Misc                        Dorart      0.00      0.00
# 16501  2010.0       Shooter                    Activision      0.01      0.00
# 16596  2010.0        Puzzle                      7G//AMES      0.00      0.01
#
#        JP_Sales  Other_Sales  Global_Sales
# 15         0.24         1.67         21.82
# 26         5.65         0.82         15.32
# 31         0.11         1.13         14.64
# 40         0.48         1.83         12.73
# 54         0.81         2.12         10.77
# ...         ...          ...           ...
# 16437      0.00         0.00          0.01
# 16478      0.01         0.00          0.01
# 16487      0.01         0.00          0.01
# 16501      0.00         0.00          0.01
# 16596      0.00         0.00          0.01
#
# [1259 rows x 11 columns]

# %%
#Make a copy of the dataframe
#Which video game had the highest sales in 2010?

#Answer = Kinect Adventures!

twenty_ten_df = df[df["Year"] == 2010]

twenty_ten_df[twenty_ten_df["Global_Sales"] == twenty_ten_df["Global_Sales"].max()]
# Out:
#     Rank                Name Platform    Year Genre               Publisher  \
# 15    16  Kinect Adventures!     X360  2010.0  Misc  Microsoft Game Studios
#
#     NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 15     14.97      4.94      0.24         1.67         21.82

# %%
#What game genre is most popular for each year

df[["Year", "Global_Sales"]].groupby(by="Year").max()
# Out:
#         Global_Sales
# Year
# 1980.0          4.31
# 1981.0          4.50
# 1982.0          7.81
# 1983.0          3.20
# 1984.0         28.31
# 1985.0         40.24
# 1986.0          6.51
# 1987.0          4.38
# 1988.0         17.28
# 1989.0         30.26
# 1990.0         20.61
# 1991.0          4.61
# 1992.0         11.18
# 1993.0         10.55
# 1994.0          9.30
# 1995.0          5.15
# 1996.0         31.37
# 1997.0         10.95
# 1998.0         14.64
# 1999.0         23.10
# 2000.0          6.39
# 2001.0         14.98
# 2002.0         16.15
# 2003.0          7.20
# 2004.0         20.81
# 2005.0         24.76
# 2006.0         82.74
# 2007.0         22.72
# 2008.0         35.82
# 2009.0         33.00
# 2010.0         21.82
# 2011.0         14.76
# 2012.0         14.03
# 2013.0         21.40
# 2014.0         11.98
# 2015.0         14.24
# 2016.0          4.77
# 2017.0          0.03
# 2020.0          0.29

# %%
#Merge or join max sales with the associated name of the game

max_sales_by_year_df = df[["Year", "Global_Sales"]].groupby(by="Year").max()
max_sales_by_year_df.merge(df[["Year", "Global_Sales", "Name"]], on=["Year", "Global_Sales"], how="left")
# Out:
#       Year  Global_Sales                                              Name
# 0   1980.0          4.31                                         Asteroids
# 1   1981.0          4.50                                          Pitfall!
# 2   1982.0          7.81                                           Pac-Man
# 3   1983.0          3.20                                          Baseball
# 4   1984.0         28.31                                         Duck Hunt
# 5   1985.0         40.24                                 Super Mario Bros.
# 6   1986.0          6.51                               The Legend of Zelda
# 7   1987.0          4.38                   Zelda II: The Adventure of Link
# 8   1988.0         17.28                               Super Mario Bros. 3
# 9   1989.0         30.26                                            Tetris
# 10  1990.0         20.61                                 Super Mario World
# 11  1991.0          4.61           The Legend of Zelda: A Link to the Past
# 12  1992.0         11.18                Super Mario Land 2: 6 Golden Coins
# 13  1993.0         10.55                             Super Mario All-Stars
# 14  1994.0          9.30                               Donkey Kong Country
# 15  1995.0          5.15         Donkey Kong Country 2: Diddy's Kong Quest
# 16  1996.0         31.37                          Pokemon Red/Pokemon Blue
# 17  1997.0         10.95                                      Gran Turismo
# 18  1998.0         14.64           Pokémon Yellow: Special Pikachu Edition
# 19  1999.0         23.10                       Pokemon Gold/Pokemon Silver
# 20  2000.0          6.39                           Pokémon Crystal Version
# 21  2001.0         14.98                            Gran Turismo 3: A-Spec
# 22  2002.0         16.15                       Grand Theft Auto: Vice City
# 23  2003.0          7.20                        Need for Speed Underground
# 24  2004.0         20.81                     Grand Theft Auto: San Andreas
# 25  2005.0         24.76                                        Nintendogs
# 26  2006.0         82.74                                        Wii Sports
# 27  2007.0         22.72                                           Wii Fit
# 28  2008.0         35.82                                    Mario Kart Wii
# 29  2009.0         33.00                                 Wii Sports Resort
# 30  2010.0         21.82                                Kinect Adventures!
# 31  2011.0         14.76                    Call of Duty: Modern Warfare 3
# 32  2012.0         14.03                        Call of Duty: Black Ops II
# 33  2013.0         21.40                                Grand Theft Auto V
# 34  2014.0         11.98                                Grand Theft Auto V
# 35  2015.0         14.24                         Call of Duty: Black Ops 3
# 36  2016.0          4.77                                           FIFA 17
# 37  2017.0          0.03  Phantasy Star Online 2 Episode 4: Deluxe Package
# 38  2020.0          0.29                            Imagine: Makeup Artist

# %%
#What are the global sales per year?

df[["Year", "Global_Sales"]].groupby("Year").sum()
# Out:
#         Global_Sales
# Year
# 1980.0         11.38
# 1981.0         35.77
# 1982.0         28.86
# 1983.0         16.79
# 1984.0         50.36
# 1985.0         53.94
# 1986.0         37.07
# 1987.0         21.74
# 1988.0         47.22
# 1989.0         73.45
# 1990.0         49.39
# 1991.0         32.23
# 1992.0         76.16
# 1993.0         45.98
# 1994.0         79.17
# 1995.0         88.11
# 1996.0        199.15
# 1997.0        200.98
# 1998.0        256.47
# 1999.0        251.27
# 2000.0        201.56
# 2001.0        331.47
# 2002.0        395.52
# 2003.0        357.85
# 2004.0        419.31
# 2005.0        459.94
# 2006.0        521.04
# 2007.0        611.13
# 2008.0        678.90
# 2009.0        667.30
# 2010.0        600.45
# 2011.0        515.99
# 2012.0        363.54
# 2013.0        368.11
# 2014.0        337.05
# 2015.0        264.44
# 2016.0         70.93
# 2017.0          0.05
# 2020.0          0.29

# %%
#Store the result

global_sales_per_year_df = df[["Year", "Global_Sales"]].groupby("Year", as_index=False).sum()

# %%
import matplotlib.pyplot as plt

# %%
global_sales_per_year_df.plot(kind="bar", x="Year", y="Global_Sales")
# Out:
# <Axes: xlabel='Year'>

# %%
#The years were scrunched too close together

global_sales_per_year_df.plot(kind="bar", x="Year", y="Global_Sales", figsize=(15,5), ylabel="Sales (Millions $)", title="Global Video Games Sales Over the Years")
# Out:
# <Axes: title={'center': 'Global Video Games Sales Over the Years'}, xlabel='Year', ylabel='Sales (Millions $)'>

# %%
#This is the answer to global sales per year

# %%
#What are the sales trends per region over time

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df[["Year", "EU_Sales", "JP_Sales", "NA_Sales", "Other_Sales", "Global_Sales"]].groupby(by="Year").sum().plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Year'>
